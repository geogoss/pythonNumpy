# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
np.random.seed(0)
A = np.random.randint(0, 10, [2, 3])
B = np.ones((2, 3))

# %%
A
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
B
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
A + B
# Out:
# array([[ 6.,  1.,  4.],
#        [ 4.,  8., 10.]])

# %% [markdown]
# ![image.png](attachment:8d19d258-c43b-44dc-b718-d73cc7023eb5.png)

# %%
 #!!!!! les tableaux doivent avoir même nombre de lignes et de colonnes
# Mais on peut étendre les dimension d'une matrice pour pouvoir les additionner => c'est le broadcasting
# exemple avec A + 2 -> 2 étant un scalaire

# %%
A
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
A + 2
# Out:
# array([[ 7,  2,  5],
#        [ 5,  9, 11]])

# %%
# de même -> voici C et D
np.random.seed(0)
C = np.random.randint(0, 10, [2, 3])
D = np.ones((2, 1))

# %%
# C et D n'ont pas la même taille -> pourtant
C + D
# Out:
# array([[ 6.,  1.,  4.],
#        [ 4.,  8., 10.]])

# %%
# D a été étendu pour pouvoir faire cette addition -> broadcasting
# Mais attention -> voici E et F

# %%
np.random.seed(0)
E = np.random.randint(0, 10, [2, 3])
F = np.ones((3, 1))

# %%
E + F
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15744/1639161992.py in <module>
# ----> 1 E + F
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,1)

# %% [markdown]
# ![image.png](attachment:e95742df-e3c0-4b9f-b529-9a0080990d7b.png)

# %% [markdown]
# ![image.png](attachment:c4ca12cf-9679-4c79-bb4e-c8afb2e5d78e.png)

# %% [markdown]
#  ![image.png](attachment:30f19043-ef73-4831-ac9b-9cee79185ee2.png)

# %%
np.random.seed(0)
G = np.random.randint(0, 10, [4, 1])
H = np.ones((1, 3))

# %%
G
# Out:
# array([[5],
#        [0],
#        [3],
#        [3]])

# %%
H
# Out:
# array([[1., 1., 1.]])

# %%
G + H
# Out:
# array([[6., 6., 6.],
#        [1., 1., 1.],
#        [4., 4., 4.],
#        [4., 4., 4.]])

# %% [markdown]
# ![image.png](attachment:971e1c4c-8649-4e43-91b8-858582f29a7d.png)
